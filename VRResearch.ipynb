# %%
›import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load the cleaned CSV
df = pd.read_csv('/content/IPQ_NASA_TLX_Cleaned.csv')

# Calculate stats
mean_hand = df['IPQ_Q1_Hand'].mean()
median_hand = df['IPQ_Q1_Hand'].median()
mode_hand = df['IPQ_Q1_Hand'].mode().values[0] if not df['IPQ_Q1_Hand'].mode().empty else None
std_hand = df['IPQ_Q1_Hand'].std()

mean_ray = df['IPQ_Q1_Ray'].mean()
median_ray = df['IPQ_Q1_Ray'].median()
mode_ray = df['IPQ_Q1_Ray'].mode().values[0] if not df['IPQ_Q1_Ray'].mode().empty else None
std_ray = df['IPQ_Q1_Ray'].std()

# Print stats
print("IPQ_Q1_Hand Statistics:")
print(f"Mean: {mean_hand:.2f}")
print(f"Median: {median_hand}")
print(f"Mode: {mode_hand}")
print(f"Standard Deviation: {std_hand:.2f}\n")

print("IPQ_Q1_Ray Statistics:")
print(f"Mean: {mean_ray:.2f}")
print(f"Median: {median_ray}")
print(f"Mode: {mode_ray}")
print(f"Standard Deviation: {std_ray:.2f}")

# Bar plot of means
plt.figure(figsize=(8,6))
bars = plt.bar(['IPQ_Q1_Hand', 'IPQ_Q1_Ray'], [mean_hand, mean_ray],
               color=['skyblue', 'lightgreen'], edgecolor='black')

# Add values on top
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.2f}', ha='center', fontsize=12)

plt.title('Mean Scores of IPQ_Q1 (Hand vs Ray)', fontsize=16)
plt.ylabel('Mean Score', fontsize=14)
plt.ylim(0, 10)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
# Out:
# IPQ_Q1_Hand Statistics:
# Mean: 8.17
# Median: 8.0
# Mode: 8
# Standard Deviation: 0.58
#
# IPQ_Q1_Ray Statistics:
# Mean: 6.83
# Median: 7.0
# Mode: 6
# Standard Deviation: 2.17

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSV
df = pd.read_csv('IPQ_NASA_TLX_Cleaned.csv')

# Prepare data in long format for seaborn
df_long = df[['IPQ_Q1_Hand', 'IPQ_Q1_Ray']].melt(var_name='Interaction', value_name='Score')

# Set seaborn style
sns.set(style='whitegrid', font_scale=1.2)

# Create boxplot with swarmplot overlay
plt.figure(figsize=(10, 7))
sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
sns.stripplot(x='Interaction', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)

plt.title('I felt like I was really inside the virtual environment', fontsize=16)
plt.xlabel('Interaction Type', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.show()
# Out:
# <ipython-input-5-a022515aebe4>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats


# Calculate stats for IPQ_Q2
mean_hand = df['IPQ_Q2_Hand'].mean()
median_hand = df['IPQ_Q2_Hand'].median()
mode_hand = df['IPQ_Q2_Hand'].mode().values[0] if not df['IPQ_Q2_Hand'].mode().empty else None
std_hand = df['IPQ_Q2_Hand'].std()

mean_ray = df['IPQ_Q2_Ray'].mean()
median_ray = df['IPQ_Q2_Ray'].median()
mode_ray = df['IPQ_Q2_Ray'].mode().values[0] if not df['IPQ_Q2_Ray'].mode().empty else None
std_ray = df['IPQ_Q2_Ray'].std()

# Print stats
print("IPQ_Q2_Hand Statistics:")
print(f"Mean: {mean_hand:.2f}")
print(f"Median: {median_hand}")
print(f"Mode: {mode_hand}")
print(f"Standard Deviation: {std_hand:.2f}\n")

print("IPQ_Q2_Ray Statistics:")
print(f"Mean: {mean_ray:.2f}")
print(f"Median: {median_ray}")
print(f"Mode: {mode_ray}")
print(f"Standard Deviation: {std_ray:.2f}")

# Bar plot of means
plt.figure(figsize=(8,6))
bars = plt.bar(['IPQ_Q2_Hand', 'IPQ_Q2_Ray'], [mean_hand, mean_ray],
               color=['skyblue', 'lightgreen'], edgecolor='black')

# Add values on top
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.2f}', ha='center', fontsize=12)

plt.title('Mean Scores of IPQ_Q2 (Hand vs Ray)', fontsize=16)
plt.ylabel('Mean Score', fontsize=14)
plt.ylim(0, 10)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
# Out:
# IPQ_Q2_Hand Statistics:
# Mean: 6.25
# Median: 6.5
# Mode: 7
# Standard Deviation: 2.01
#
# IPQ_Q2_Ray Statistics:
# Mean: 6.25
# Median: 6.0
# Mode: 5
# Standard Deviation: 1.76

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSV
df = pd.read_csv('IPQ_NASA_TLX_Cleaned.csv')

# Prepare data in long format for seaborn (for IPQ_Q2)
df_long = df[['IPQ_Q2_Hand', 'IPQ_Q2_Ray']].melt(var_name='Interaction', value_name='Score')

# Set seaborn style
sns.set(style='whitegrid', font_scale=1.2)

# Create boxplot with swarmplot overlay
plt.figure(figsize=(10, 7))
sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
sns.stripplot(x='Interaction', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)

plt.title('How real did the virtual world seem to you?', fontsize=16)
plt.xlabel('Interaction Type', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.show()
# Out:
# <ipython-input-9-25da77a93318>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')

# %% [markdown]
# ## **I had a sense of acting in the virtual space, rather than operating something from outside.**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats



# Calculate stats for IPQ_Q3
mean_hand = df['IPQ_Q3_Hand'].mean()
median_hand = df['IPQ_Q3_Hand'].median()
mode_hand = df['IPQ_Q3_Hand'].mode().values[0] if not df['IPQ_Q3_Hand'].mode().empty else None
std_hand = df['IPQ_Q3_Hand'].std()

mean_ray = df['IPQ_Q3_Ray'].mean()
median_ray = df['IPQ_Q3_Ray'].median()
mode_ray = df['IPQ_Q3_Ray'].mode().values[0] if not df['IPQ_Q3_Ray'].mode().empty else None
std_ray = df['IPQ_Q3_Ray'].std()

# Print stats
print("IPQ_Q3_Hand Statistics:")
print(f"Mean: {mean_hand:.2f}")
print(f"Median: {median_hand}")
print(f"Mode: {mode_hand}")
print(f"Standard Deviation: {std_hand:.2f}\n")

print("IPQ_Q3_Ray Statistics:")
print(f"Mean: {mean_ray:.2f}")
print(f"Median: {median_ray}")
print(f"Mode: {mode_ray}")
print(f"Standard Deviation: {std_ray:.2f}")

# Bar plot of means
plt.figure(figsize=(8,6))
bars = plt.bar(['IPQ_Q3_Hand', 'IPQ_Q3_Ray'], [mean_hand, mean_ray],
               color=['skyblue', 'lightgreen'], edgecolor='black')

# Add values on top
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.2f}', ha='center', fontsize=12)

plt.title('Mean Scores of IPQ_Q3 (Hand vs Ray)', fontsize=16)
plt.ylabel('Mean Score', fontsize=14)
plt.ylim(0, 10)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
# Out:
# IPQ_Q3_Hand Statistics:
# Mean: 6.75
# Median: 7.0
# Mode: 7
# Standard Deviation: 2.80
#
# IPQ_Q3_Ray Statistics:
# Mean: 6.00
# Median: 6.5
# Mode: 2
# Standard Deviation: 2.86

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSV
df = pd.read_csv('IPQ_NASA_TLX_Cleaned.csv')

# Prepare data in long format for seaborn (for IPQ_Q3)
df_long = df[['IPQ_Q3_Hand', 'IPQ_Q3_Ray']].melt(var_name='Interaction', value_name='Score')

# Set seaborn style
sns.set(style='whitegrid', font_scale=1.2)

# Create boxplot with swarmplot overlay
plt.figure(figsize=(10, 7))
sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
sns.stripplot(x='Interaction', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)

plt.title('I had a sense of acting in the virtual space', fontsize=16)
plt.xlabel('Interaction Type', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.show()
# Out:
# <ipython-input-12-b1109666b86d>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')

# %% [markdown]
# ## **How aware were you of the real world surrounding while navigating in the virtual world? (i.e. sounds, room temperature, other people, etc.)?**

# %%
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats

# Load the cleaned CSV
df = pd.read_csv('/content/IPQ_NASA_TLX_Cleaned.csv')

# Calculate stats for IPQ_Q4
mean_hand = df['IPQ_Q4_Hand'].mean()
median_hand = df['IPQ_Q4_Hand'].median()
mode_hand = df['IPQ_Q4_Hand'].mode().values[0] if not df['IPQ_Q4_Hand'].mode().empty else None
std_hand = df['IPQ_Q4_Hand'].std()

mean_ray = df['IPQ_Q4_Ray'].mean()
median_ray = df['IPQ_Q4_Ray'].median()
mode_ray = df['IPQ_Q4_Ray'].mode().values[0] if not df['IPQ_Q4_Ray'].mode().empty else None
std_ray = df['IPQ_Q4_Ray'].std()

# Print stats
print("IPQ_Q4_Hand Statistics:")
print(f"Mean: {mean_hand:.2f}")
print(f"Median: {median_hand}")
print(f"Mode: {mode_hand}")
print(f"Standard Deviation: {std_hand:.2f}\n")

print("IPQ_Q4_Ray Statistics:")
print(f"Mean: {mean_ray:.2f}")
print(f"Median: {median_ray}")
print(f"Mode: {mode_ray}")
print(f"Standard Deviation: {std_ray:.2f}")

# Bar plot of means
plt.figure(figsize=(8,6))
bars = plt.bar(['IPQ_Q4_Hand', 'IPQ_Q4_Ray'], [mean_hand, mean_ray],
               color=['skyblue', 'lightgreen'], edgecolor='black')

# Add values on top
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.2f}', ha='center', fontsize=12)

plt.title('Mean Scores of IPQ_Q4 (Hand vs Ray)', fontsize=16)
plt.ylabel('Mean Score', fontsize=14)
plt.ylim(0, 10)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()
# Out:
# IPQ_Q4_Hand Statistics:
# Mean: 5.25
# Median: 5.0
# Mode: 8
# Standard Deviation: 2.96
#
# IPQ_Q4_Ray Statistics:
# Mean: 5.92
# Median: 5.5
# Mode: 5
# Standard Deviation: 2.61

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSV
df = pd.read_csv('IPQ_NASA_TLX_Cleaned.csv')

# Prepare data in long format for seaborn (for IPQ_Q4)
df_long = df[['IPQ_Q4_Hand', 'IPQ_Q4_Ray']].melt(var_name='Interaction', value_name='Score')

# Set seaborn style
sns.set(style='whitegrid', font_scale=1.2)

# Create boxplot with swarmplot overlay
plt.figure(figsize=(10, 7))
sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
sns.stripplot(x='Interaction', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)

plt.title('How aware were you of the real world while navigating?', fontsize=16)
plt.xlabel('Interaction Type', fontsize=14)
plt.ylabel('Score', fontsize=14)
plt.show()
# Out:
# <ipython-input-14-c99d12188f7f>:16: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSV
df = pd.read_csv('/content/IPQ_NASA_TLX_Cleaned.csv')

# Question titles from Google Form
nasa_titles = {
    1: 'How mentally demanding was the task?',
    2: 'How physically demanding was the task?',
    3: 'How hurried or rushed did you feel?',
    4: 'How successful do you feel you were at completing the task?',
    5: 'How hard did you have to work to accomplish the task?',
    6: 'How irritated, stressed, or annoyed were you while completing the task?'
}

# Loop through NASA questions
for qnum in range(1, 7):
    hand_col = f'NASA_Q{qnum}_Hand'
    ray_col = f'NASA_Q{qnum}_Ray'

    # Calculate stats
    mean_hand = df[hand_col].mean()
    median_hand = df[hand_col].median()
    mode_hand = df[hand_col].mode().values[0] if not df[hand_col].mode().empty else None
    std_hand = df[hand_col].std()

    mean_ray = df[ray_col].mean()
    median_ray = df[ray_col].median()
    mode_ray = df[ray_col].mode().values[0] if not df[ray_col].mode().empty else None
    std_ray = df[ray_col].std()

    # Print stats
    print(f"{hand_col} Statistics:")
    print(f"Mean: {mean_hand:.2f}")
    print(f"Median: {median_hand}")
    print(f"Mode: {mode_hand}")
    print(f"Standard Deviation: {std_hand:.2f}\n")

    print(f"{ray_col} Statistics:")
    print(f"Mean: {mean_ray:.2f}")
    print(f"Median: {median_ray}")
    print(f"Mode: {mode_ray}")
    print(f"Standard Deviation: {std_ray:.2f}\n")

    # --- Bar plot ---
    plt.figure(figsize=(8,6))
    bars = plt.bar([hand_col, ray_col], [mean_hand, mean_ray],
                   color=['skyblue', 'lightgreen'], edgecolor='black')
    for bar in bars:
        height = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2., height + 0.1, f'{height:.2f}', ha='center', fontsize=12)
    plt.title(f"Mean Scores: {nasa_titles[qnum]}", fontsize=16)
    plt.ylabel('Mean Score', fontsize=14)
    plt.ylim(0, 10)
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.show()

    # --- Boxplot + stripplot ---
    df_long = df[[hand_col, ray_col]].melt(var_name='Interaction', value_name='Score')
    sns.set(style='whitegrid', font_scale=1.2)
    plt.figure(figsize=(10,7))
    sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
    sns.stripplot(x='Interaction', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)
    plt.title(nasa_titles[qnum], fontsize=16)
    plt.xlabel('Interaction Type', fontsize=14)
    plt.ylabel('Score', fontsize=14)
    plt.show()
# Out:
# NASA_Q1_Hand Statistics:
# Mean: 6.17
# Median: 7.0
# Mode: 9
# Standard Deviation: 2.89
#
# NASA_Q1_Ray Statistics:
# Mean: 4.08
# Median: 4.0
# Mode: 2
# Standard Deviation: 2.11
# <ipython-input-15-847f847c0e90>:64: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
# NASA_Q2_Hand Statistics:
# Mean: 4.17
# Median: 3.0
# Mode: 1
# Standard Deviation: 3.38
#
# NASA_Q2_Ray Statistics:
# Mean: 2.42
# Median: 2.0
# Mode: 1
# Standard Deviation: 1.88
# <ipython-input-15-847f847c0e90>:64: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interaction', y='Score', data=df_long, palette='pastel')
# NASA_Q3_Hand Statistics:
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned CSVs
df_ray = pd.read_csv('/content/Ray_Interactor_Cleaned.csv')
df_hand = pd.read_csv('/content/Hand_Interactor_Cleaned.csv')

# Get numeric scores
ray_scores = df_ray['Numeric_Score']
hand_scores = df_hand['Numeric_Score']

# Compute stats
mean_ray = ray_scores.mean()
median_ray = ray_scores.median()
mode_ray = ray_scores.mode().values[0] if not ray_scores.mode().empty else None
std_ray = ray_scores.std()

mean_hand = hand_scores.mean()
median_hand = hand_scores.median()
mode_hand = hand_scores.mode().values[0] if not hand_scores.mode().empty else None
std_hand = hand_scores.std()

# Print stats
print("Ray Interactor Stats:")
print(f"Mean: {mean_ray:.2f}")
print(f"Median: {median_ray}")
print(f"Mode: {mode_ray}")
print(f"Standard Deviation: {std_ray:.2f}\n")

print("Hand Interactor Stats:")
print(f"Mean: {mean_hand:.2f}")
print(f"Median: {median_hand}")
print(f"Mode: {mode_hand}")
print(f"Standard Deviation: {std_hand:.2f}")

# --- Bar plot of means ---
plt.figure(figsize=(8,6))
bars = plt.bar(['Ray Interactor', 'Hand Interactor'], [mean_ray, mean_hand],
               color=['skyblue', 'lightgreen'], edgecolor='black')

for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2., height + 0.05, f'{height:.2f}', ha='center', fontsize=12)

plt.title('Average Correct Answers', fontsize=16)
plt.ylabel('Average Score (out of 6)', fontsize=14)
plt.ylim(0, 6)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()

# --- Boxplot of scores ---
# Prepare long format for seaborn
df_long = pd.DataFrame({
    'Interactor': ['Ray'] * len(ray_scores) + ['Hand'] * len(hand_scores),
    'Score': pd.concat([ray_scores, hand_scores], ignore_index=True)
})

plt.figure(figsize=(10,7))
sns.boxplot(x='Interactor', y='Score', data=df_long, palette='pastel')
sns.stripplot(x='Interactor', y='Score', data=df_long, color='black', size=8, jitter=True, alpha=0.7)

plt.title('Score Distributions by Interactor', fontsize=16)
plt.xlabel('Interaction Type', fontsize=14)
plt.ylabel('Correct Answers (out of 6)', fontsize=14)
plt.show()
# Out:
# Ray Interactor Stats:
# Mean: 5.33
# Median: 6.0
# Mode: 6
# Standard Deviation: 0.98
#
# Hand Interactor Stats:
# Mean: 4.33
# Median: 6.0
# Mode: 6
# Standard Deviation: 2.39
# <ipython-input-16-3adf620ade12>:60: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Interactor', y='Score', data=df_long, palette='pastel')
